# %%
import pandas as pd

# %%
data = pd.read_csv("/home/lhe339/data/memory-z-rag/data/docs_triviaqa_50.csv")
data.head()
# Out:
#                                                 text  \
# 0  Patricia Neary (born October 27, 1942) is an A...
# 1  Evening Class is a novel by Maeve Binchy. It w...
# 2  Spy Hook is a 1988 spy novel by Len Deighton. ...
# 3  "Let Your Love Flow" is the title of a pop son...
# 4  "Lightnin' Strikes" is a song written by Lou C...
#
#                                            input_ids  \
# 0  [28205, 46291, 4275, 661, 320, 16381, 6664, 22...
# 1  [13461, 287, 3308, 374, 264, 11775, 555, 65914...
# 2  [45127, 29271, 374, 264, 220, 3753, 23, 21930,...
# 3  [1, 10267, 4718, 10919, 23260, 1, 374, 279, 23...
# 4  [1, 14235, 79560, 6, 98126, 1, 374, 264, 5609,...
#
#                                              queries  \
# 0  ["In which branch of the arts is Patricia Near...
# 1             ["Who wrote the novel Evening Class?"]
# 2  ["Who had the noels Spy Hook and Spy Line publ...
# 3  ["Who had a 70s No 1 hit with Let Your Love Fl...
# ...

# %%
data.iloc[0]
# Out:
# text         Patricia Neary (born October 27, 1942) is an A...
# input_ids    [28205, 46291, 4275, 661, 320, 16381, 6664, 22...
# queries      ["In which branch of the arts is Patricia Near...
# answers      ["1938 ballet premieres", "Ballet teachers", "...
# doc_sum      Patricia Neary, born October 27, 1942, in Miam...
# Name: 0, dtype: str

# %%
print(data.iloc[0]['text'])
print("---")
print(len((data.iloc[0]['text']).split()))
# Out:
# Patricia Neary (born October 27, 1942) is an American ballerina, choreographer and ballet director, who has been particularly active in Switzerland. She has also been a highly successful ambassador for the Balanchine Trust, bringing George Balanchine's ballets to some 60 cities around the globe.
#
# Biography
#
# Born in Miami, Florida, she first studied there under George Milenoff and Thomas Armour until she attended the School of American Ballet in New York.
#
# At the age of 14, she joined the National Ballet of Canada as the youngest dancer in the company. In 1960, she became a member of the New York City Ballet where she performed almost all the ballerina roles in George Balanchine's major works, including two roles he created specially for her in Raymonda Variations (1961) and Jewels (1967). She also performed leading roles in ballets by Jerome Robbins, Antony Tudor, John Taras and Merce Cunningham.
#
# ...

# %%
print(data.iloc[0]['input_ids'])
print("---")
print(len((data.iloc[0]['input_ids']).split()))
# Out:
# [28205, 46291, 4275, 661, 320, 16381, 6664, 220, 1544, 11, 220, 6393, 17, 8, 374, 459, 3778, 5041, 261, 2259, 11, 50671, 42606, 323, 71310, 7690, 11, 889, 706, 1027, 8104, 4642, 304, 30221, 13, 3005, 706, 1101, 1027, 264, 7701, 6992, 37756, 369, 279, 19984, 3581, 483, 17236, 11, 12967, 10058, 19984, 3581, 483, 596, 71310, 82, 311, 1063, 220, 1399, 9919, 2212, 279, 24867, 382, 37196, 5814, 271, 59204, 304, 18045, 11, 9784, 11, 1364, 1176, 20041, 1070, 1234, 10058, 10357, 268, 1885, 323, 11355, 61685, 3156, 1364, 18677, 279, 6150, 315, 3778, 87736, 304, 1561, 4356, 13, 4815, 1688, 279, 4325, 315, 220, 975, 11, 1364, 11096, 279, 5165, 87736, 315, 7008, 439, 279, 39637, 64682, 304, 279, 2883, 13, 763, 220, 5162, 15, 11, 1364, 6244, 264, 4562, 315, 279, 1561, 4356, 4409, 87736, 1405, 1364, 10887, 4661, 682, 279, 5041, 261, 2259, 13073, 304, 10058, 19984, 3581, 483, 596, 3682, 4375, 11, 2737, 1403, 13073, 568, 3549, 35426, 369, 1077, 304, 13558, 1677, 3315, 28968, 811, 320, 5162, 16, 8, 32
# ...

# %%
print(data.iloc[0]['queries'])
# Out:
# ["In which branch of the arts is Patricia Neary famous?"]

# %%
print(data.iloc[0]['answers'])
print("---")
print(len((data.iloc[0]['answers']).split()))
# Out:
# ["1938 ballet premieres", "Ballet teachers", "Classical Dance", "1914 ballet premieres", "Balletomane", "2011 ballet premieres", "Balletomanes", "Ballets", "Ballet lessons", "Ballet competitions", "Ballet schools", "Ballet characters", "Ballet", "Balet", "Ballet dancing", "1940 ballet premieres", "Ballett", "Ballet dance", "Balet, India", "Classical dance", "Balletto", "1915 ballet premieres", "UN/LOCODE:INBLT", "1916 ballet premieres", "Balletti", "1939 ballet premieres"]
# ---
# 50

# %%
print(data.iloc[0]['doc_sum'])
print("---")
print(len((data.iloc[0]['doc_sum']).split()))
# Out:
# Patricia Neary, born October 27, 1942, in Miami, Florida, is an American ballerina, choreographer, and ballet director, notably active in Switzerland. After training at the School of American Ballet, she joined the National Ballet of Canada at 14 and later the New York City Ballet in 1960, originating roles in George Balanchine's *Raymonda Variations* (1961) and *Jewels* (1967). Neary also performed extensively with the Geneva Ballet, Deutsche Oper Berlin (1970-73), Grand Théâtre de Genève (1973-78), Zurich Ballet (1978-85), La Scala (1986-87), and Ballet British Columbia (1989-90). Since 1988, she has been an ambassador for the Balanchine Trust, presenting his ballets globally.
# ---
# 101
